# %% [markdown]
# <a href="https://colab.research.google.com/github/irullah/prosaindata/blob/main/crawling_twitter.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !git clone --depth=1 https://github.com/twintproject/twint.git
# %cd twint
# !pip3 install . -r requirements.txt
# Out:
# Cloning into 'twint'...
# remote: Enumerating objects: 47, done.
# remote: Counting objects: 100% (47/47), done.
# remote: Compressing objects: 100% (44/44), done.
# remote: Total 47 (delta 3), reused 14 (delta 0), pack-reused 0
# Unpacking objects: 100% (47/47), 42.93 KiB | 3.58 MiB/s, done.
# /content/twint
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Processing /content/twint
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 266.0/266.0 KB 24.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 385.4/385.4 KB 21.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.4/50.4 KB 8.1 MB/s eta 0:00:00
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 289.0/289.0 KB 35.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.5/59.5 KB 9.2 MB/s eta 0:00:00
# ...

# %%
# !pip install twint
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
# !pip install nest_asyncio
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
# !pip install aiohttp==3.7.0
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 56.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 133.4/133.4 KB 14.5 MB/s eta 0:00:00
# ...
#   Attempting uninstall: chardet
#     Found existing installation: chardet 4.0.0
#     Uninstalling chardet-4.0.0:
#       Successfully uninstalled chardet-4.0.0
#   Attempting uninstall: async-timeout
#     Found existing installation: async-timeout 4.0.2
#     Uninstalling async-timeout-4.0.2:
#       Successfully uninstalled async-timeout-4.0.2
#   Attempting uninstall: aiohttp
#     Found existing installation: aiohttp 3.8.4
#     Uninstalling aiohttp-3.8.4:
#       Successfully uninstalled aiohttp-3.8.4
# ...

# %%
import nest_asyncio
nest_asyncio.apply()

# %%
import twint

# %%
#configuration
c = twint.Config()
c.Store_csv = True
c.Search = "@ridwankamil"
c.Limit = 500
c.Custom["tweet"] = ["username","tweet"]
c.Pandas = True
c.Output = "ridwankamiltweet.csv"

# %%
#run
twint.run.Search(c)
# Out:
# 1628330759542169602 2023-02-22 09:48:00 +0000 <rkrijuara> Gubernur Jabar @ridwankamil  bersama Walikota Banjar Meninjau Pasar Banjar, Selasa 22 Februari 2023  #RidwanKamil #rkri #rkrijuara #JabarJuara #IndonesiaJuara  https://t.co/Kkemwi58xc
# 1628329569169330177 2023-02-22 09:43:16 +0000 <magfian> @JantunGPiisanG Niatnya mau ribut mau berantem tapi sadar lagi dikota orang,lagi bertamu Di tahan istri juga ga boleh emosi @ridwankamil  Gimana nih kang! Preman nya udah ga terkendali  Urang arek baledog eta bengeut preman na
# 1628329235554390018 2023-02-22 09:41:57 +0000 <NiardaSharif> "Yang terhormat Gubernur Jawa Barat Bapak Ridwan Kamil. Terima kasih Bapak Gubernur @ridwankamil sudah mengundang saya untuk mengklarifikasi situasi kondisi yang ada di Indramayu.
# 1628329103811280896 2023-02-22 09:41:25 +0000 <tikanuca> @JantunGPiisanG @ridwankamil halo pak
# ...

# %%
# import shutil

# %%
# file_output = "/content/twint/ridwankamiltweet.csv"
# gdrive_link = "/content/drive/MyDrive/prosaindata/"
# shutil.move(file_output, gdrive_link)
# Out:
# '/content/drive/MyDrive/prosaindata/ridwankamiltweet.csv'
